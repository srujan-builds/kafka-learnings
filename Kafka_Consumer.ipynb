# %%
from kafka import KafkaConsumer

# %%
consumer = KafkaConsumer(
    bootstrap_servers = ['localhost:9092'],
    group_id = "test-cg",
    key_deserializer = lambda m: m.decode('utf-8'),
    value_deserializer = lambda m: m.decode('utf-8')
)

# %%
#subscribe to topic
consumer.subscribe(['my-first-topic'])

# %%
try:
    while True:
        record = consumer.poll(timeout_ms=5000)
        for topic_partition, messages in record.items():
            for message in messages:
                print(f"Topic:{message.topic}, Partition:{message.partition}, Offset:{message.offset}")
                print(f"Key:{message.key}, Value:{message.value}")
finally:
    consumer.close()
# Out:
# Topic:my-first-topic, Partition:0, Offset:10
# Key:key-0, Value:value-0
# Topic:my-first-topic, Partition:0, Offset:11
# Key:key-1, Value:value-1
# Topic:my-first-topic, Partition:0, Offset:12
# Key:key-2, Value:value-2
# Topic:my-first-topic, Partition:0, Offset:13
# Key:key-3, Value:value-3
# Topic:my-first-topic, Partition:0, Offset:14
# Key:key-4, Value:value-4
# Topic:my-first-topic, Partition:0, Offset:15
# Key:key-5, Value:value-5
# Topic:my-first-topic, Partition:0, Offset:16
# Key:key-6, Value:value-6
# Topic:my-first-topic, Partition:0, Offset:17
# Key:key-7, Value:value-7
# Topic:my-first-topic, Partition:0, Offset:18
# Key:key-8, Value:value-8
# Topic:my-first-topic, Partition:0, Offset:19
# Key:key-9, Value:value-9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 try:
#       2     while True:
# ----> 3         record = consumer.poll(timeout_ms=5000)
#       4         for topic_partition, messages in record.items():
#       5             for message in messages:
#
# File ~\Desktop\Data Engineer\Apache Kafka\kafka-learning\venv\lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~\Desktop\Data Engineer\Apache Kafka\kafka-learning\venv\lib\site-packages\kafka\consumer\group.py:731, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     728     log.debug('poll: do not have all fetch positions...')
#     729     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 731 self._client.poll(timeout_ms=poll_timeout_ms)
#     732 # after the long poll, we should check whether the group needs to rebalance
#     733 # prior to returning data so that the group can stabilize faster
#     734 if self._coordinator.need_rejoin():
#
# File ~\Desktop\Data Engineer\Apache Kafka\kafka-learning\venv\lib\site-packages\kafka\client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File ~\Desktop\Data Engineer\Apache Kafka\kafka-learning\venv\lib\site-packages\kafka\client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python310\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
